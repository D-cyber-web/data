# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns',100)

df = pd.read_csv('fifa.csv')

# %%
df.head()
# Out:
#          date home_team     away_team home_team_continent away_team_continent  \
# 0  1993-08-08   Bolivia       Uruguay       South America       South America
# 1  1993-08-08    Brazil        Mexico       South America       North America
# 2  1993-08-08   Ecuador     Venezuela       South America       South America
# 3  1993-08-08    Guinea  Sierra Leone              Africa              Africa
# 4  1993-08-08  Paraguay     Argentina       South America       South America
#
#    home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# 0                   59                   22                            0
# 1                    8                   14                            0
# 2                   35                   94                            0
# 3                   65                   86                            0
# 4                   67                    5                            0
#
# ...

# %%
df.tail(2)
# Out:
#              date       home_team away_team home_team_continent  \
# 23919  2022-06-14           Japan   Tunisia                Asia
# 23920  2022-06-14  Korea Republic     Egypt                Asia
#
#       away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 23919              Africa                   23                   35
# 23920              Africa                   29                   32
#
#        home_team_total_fifa_points  away_team_total_fifa_points  \
# 23919                         1553                         1499
# 23920                         1519                         1500
#
#        home_team_score  away_team_score tournament   city         country  \
# 23919                0                3  Kirin Cup  Suita           Japan
# 23920                4                1   Friendly  Seoul  Korea Republic
#
#        neutral_location shoot_out home_team_result  \
# 23919             False        No             Lose
# ...

# %%
df.columns
# Out:
# Index(['date', 'home_team', 'away_team', 'home_team_continent',
#        'away_team_continent', 'home_team_fifa_rank', 'away_team_fifa_rank',
#        'home_team_total_fifa_points', 'away_team_total_fifa_points',
#        'home_team_score', 'away_team_score', 'tournament', 'city', 'country',
#        'neutral_location', 'shoot_out', 'home_team_result',
#        'home_team_goalkeeper_score', 'away_team_goalkeeper_score',
#        'home_team_mean_defense_score', 'home_team_mean_offense_score',
#        'home_team_mean_midfield_score', 'away_team_mean_defense_score',
#        'away_team_mean_offense_score', 'away_team_mean_midfield_score'],
#       dtype='object')

# %%
len(df)
# Out:
# 23921

# %%
df.query("home_team_fifa_rank>away_team_fifa_rank")
# Out:
#              date               home_team    away_team home_team_continent  \
# 0      1993-08-08                 Bolivia      Uruguay       South America
# 4      1993-08-08                Paraguay    Argentina       South America
# 5      1993-08-08                    Peru     Colombia       South America
# 8      1993-08-11           Faroe Islands       Norway              Europe
# 9      1993-08-11                  Sweden  Switzerland              Europe
# ...           ...                     ...          ...                 ...
# 23909  2022-06-14                  Poland      Belgium              Europe
# 23910  2022-06-14                 Armenia     Scotland              Europe
# 23912  2022-06-14  Bosnia and Herzegovina      Finland              Europe
# 23916  2022-06-14                 Moldova      Andorra              Europe
# 23917  2022-06-14           Liechtenstein       Latvia              Europe
#
# ...

# %%
df.iloc[:10 ,4:9]
# Out:
#   away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0       South America                   59                   22
# 1       North America                    8                   14
# 2       South America                   35                   94
# 3              Africa                   65                   86
# 4       South America                   67                    5
# 5       South America                   70                   19
# 6              Africa                   50                  102
# 7              Africa                   65                   86
# 8              Europe                  111                    9
# 9              Europe                    4                    3
#
#    home_team_total_fifa_points  away_team_total_fifa_points
# 0                            0                            0
# 1                            0                            0
# 2                            0                            0
# ...

# %%
df.loc[[3,4,21,26], ['home_team','away_team','home_team_fifa_rank']]
# Out:
#    home_team     away_team  home_team_fifa_rank
# 3     Guinea  Sierra Leone                   65
# 4   Paraguay     Argentina                   67
# 21   Denmark     Lithuania                   10
# 26   Iceland           USA                   53

# %%
df = df.drop(columns = ['tournament'])

# %%
df.head()
# Out:
#          date home_team     away_team home_team_continent away_team_continent  \
# 0  1993-08-08   Bolivia       Uruguay       South America       South America
# 1  1993-08-08    Brazil        Mexico       South America       North America
# 2  1993-08-08   Ecuador     Venezuela       South America       South America
# 3  1993-08-08    Guinea  Sierra Leone              Africa              Africa
# 4  1993-08-08  Paraguay     Argentina       South America       South America
#
#    home_team_fifa_rank  away_team_fifa_rank  home_team_total_fifa_points  \
# 0                   59                   22                            0
# 1                    8                   14                            0
# 2                   35                   94                            0
# 3                   65                   86                            0
# 4                   67                    5                            0
#
# ...

# %%
df.home_team_fifa_rank.dtypes
# Out:
# dtype('int64')

# %%
df.dtypes
# Out:
# date                              object
# home_team                         object
# away_team                         object
# home_team_continent               object
# away_team_continent               object
# home_team_fifa_rank                int64
# away_team_fifa_rank                int64
# home_team_total_fifa_points        int64
# away_team_total_fifa_points        int64
# home_team_score                    int64
# away_team_score                    int64
# city                              object
# country                           object
# neutral_location                    bool
# shoot_out                         object
# home_team_result                  object
# home_team_goalkeeper_score       float64
# away_team_goalkeeper_score       float64
# home_team_mean_defense_score     float64
# home_team_mean_offense_score     float64
# home_team_mean_midfield_score    float64
# away_team_mean_defense_score     float64
# away_team_mean_offense_score     float64
# ...

# %%
random_col = np.random

# %%
random_col = np.random.randint(100, size=len(df))

# %%
df.insert(3, 'numbers', random_col)

# %%
df.head()
# Out:
#          date home_team     away_team  numbers home_team_continent  \
# 0  1993-08-08   Bolivia       Uruguay       19       South America
# 1  1993-08-08    Brazil        Mexico       15       South America
# 2  1993-08-08   Ecuador     Venezuela       92       South America
# 3  1993-08-08    Guinea  Sierra Leone       99              Africa
# 4  1993-08-08  Paraguay     Argentina       10       South America
#
#   away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0       South America                   59                   22
# 1       North America                    8                   14
# 2       South America                   35                   94
# 3              Africa                   65                   86
# 4       South America                   67                    5
#
#    home_team_total_fifa_points  away_team_total_fifa_points  home_team_score  \
# 0                            0                            0                3
# ...

# %%
df.rename(columns = {"numbers": "hagga_ww"})
# Out:
#              date       home_team     away_team  hagga_ww home_team_continent  \
# 0      1993-08-08         Bolivia       Uruguay        19       South America
# 1      1993-08-08          Brazil        Mexico        15       South America
# 2      1993-08-08         Ecuador     Venezuela        92       South America
# 3      1993-08-08          Guinea  Sierra Leone        99              Africa
# 4      1993-08-08        Paraguay     Argentina        10       South America
# ...           ...             ...           ...       ...                 ...
# 23916  2022-06-14         Moldova       Andorra        25              Europe
# 23917  2022-06-14   Liechtenstein        Latvia         5              Europe
# 23918  2022-06-14           Chile         Ghana        32       South America
# 23919  2022-06-14           Japan       Tunisia         9                Asia
# 23920  2022-06-14  Korea Republic         Egypt        17                Asia
#
# ...

# %%
#grouping
df.groupby("country")['home_team_total_fifa_points'].sum()
# Out:
# country
# Afghanistan      213
# Albania        46371
# Algeria        48663
# Andorra        24976
# Angola         24834
#                ...
# Vietnam        23542
# Wales          59753
# Yemen            140
# Zambia         36237
# Zimbabwe       17338
# Name: home_team_total_fifa_points, Length: 217, dtype: int64

# %%
df.count(0)
# Out:
# date                             23921
# home_team                        23921
# away_team                        23921
# numbers                          23921
# home_team_continent              23921
# away_team_continent              23921
# home_team_fifa_rank              23921
# away_team_fifa_rank              23921
# home_team_total_fifa_points      23921
# away_team_total_fifa_points      23921
# home_team_score                  23921
# away_team_score                  23921
# city                             23921
# country                          23921
# neutral_location                 23921
# shoot_out                        23921
# home_team_result                 23921
# home_team_goalkeeper_score        8379
# away_team_goalkeeper_score        8095
# home_team_mean_defense_score      7787
# home_team_mean_offense_score      8510
# home_team_mean_midfield_score     8162
# away_team_mean_defense_score      7564
# away_team_mean_offense_score      8312
# ...

# %%
df['home_team_score'].describe()
# Out:
# count    23921.000000
# mean         1.609214
# std          1.630127
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max         31.000000
# Name: home_team_score, dtype: float64

# %%
df['home_team_score'].explode()
# Out:
# 0        3
# 1        1
# 2        5
# 3        1
# 4        1
#         ..
# 23916    2
# 23917    0
# 23918    0
# 23919    0
# 23920    4
# Name: home_team_score, Length: 23921, dtype: int64

# %%
 df['home_team_fifa_rank'].cumsum()
# Out:
# 0             59
# 1             67
# 2            102
# 3            167
# 4            234
#           ...
# 23916    1862090
# 23917    1862282
# 23918    1862310
# 23919    1862333
# 23920    1862362
# Name: home_team_fifa_rank, Length: 23921, dtype: int64

# %%
df['country'].count()
# Out:
# 23921

# %%
df['home_team_mean_defense_score'].count()
# Out:
# 7787

# %%
#help(df.pivot)

# %%
df
# Out:
#              date       home_team     away_team home_team_continent  \
# 0      1993-08-08         Bolivia       Uruguay       South America
# 1      1993-08-08          Brazil        Mexico       South America
# 2      1993-08-08         Ecuador     Venezuela       South America
# 3      1993-08-08          Guinea  Sierra Leone              Africa
# 4      1993-08-08        Paraguay     Argentina       South America
# ...           ...             ...           ...                 ...
# 23916  2022-06-14         Moldova       Andorra              Europe
# 23917  2022-06-14   Liechtenstein        Latvia              Europe
# 23918  2022-06-14           Chile         Ghana       South America
# 23919  2022-06-14           Japan       Tunisia                Asia
# 23920  2022-06-14  Korea Republic         Egypt                Asia
#
#       away_team_continent  home_team_fifa_rank  away_team_fifa_rank  \
# 0           South America                   59                   22
# ...

# %%
Quantity = df[['Name','Product','Quantity']]

# %%
pd.pivot(data=Quantity, index='Name', columns= 'Product',values='Quantity')
